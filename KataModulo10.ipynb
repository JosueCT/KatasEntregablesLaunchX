# %% [markdown]
# ## Ejercico10: Tracebacks

# %%
open("/archivos/imagen.jpg")

def main():
    open("/archivos/imagen.jpg")

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Josué\Documents\Curso Python\KataModulo0\KataModulo10.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Josu%C3%A9/Documents/Curso%20Python/KataModulo0/KataModulo10.ipynb#ch0000000?line=0'>1</a> open("/archivos/imagen.jpg")
#       <a href='vscode-notebook-cell:/c%3A/Users/Josu%C3%A9/Documents/Curso%20Python/KataModulo0/KataModulo10.ipynb#ch0000000?line=2'>3</a> def main():
#       <a href='vscode-notebook-cell:/c%3A/Users/Josu%C3%A9/Documents/Curso%20Python/KataModulo0/KataModulo10.ipynb#ch0000000?line=3'>4</a>     open("/archivos/imagen.jpg")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/archivos/imagen.jpg'

# %%
try:
    open('configuracion.txt')
except FileNotFoundError:
     print("Nadie sabe donde dejaste el archivo configuracion.txt!")
# Out:
# Nadie saber donde dejaste el archivo config.txt!

# %%
def main():
    try:
        configuration = open('configuracion.txt')
    except FileNotFoundError:
        print("Nadie sabe donde dejaste el archivo configuracion.txt!")


if __name__ == '__main__':
    main()
# Out:
# Nadie sabe donde dejaste el archivo config.txt!

# %%
def main():
    try:
        configuration = open('config.py')
    except FileNotFoundError:
        print("Nadie sabe donde dejaste el archivo configuracion.txt!")


if __name__ == '__main__':
    main()
# Out:
# Nadie sabe donde dejaste el archivo config.txt!

# %%
def main():
    try:
        configuration = open('configuracion.txt')
    except Exception:
        print("Nadie sabe donde dejaste el archivo configuracion.txt!")

# %%
def main():
    try:
        configuration = open('configuracion.txt')
    except FileNotFoundError:
        print("Nadie sabe donde dejaste el archivo configuracion.txt!")
    except IsADirectoryError:
        print("Encontré configuracion.txt pero es un directorio, no pude leerlo")

# %%
def main():
    try:
        configuration = open('configuracion.txt')
    except FileNotFoundError:
        print("Nadie sabe donde dejaste el archivo configuracion.txt!")
    except IsADirectoryError:
        print("Encontré configuracion.txt pero es un directorio, no pude leerlo")
    except (BlockingIOError, TimeoutError):
        print("Sistema de archivos con mucha carga, no se puede completar la lectura del archivo de configuración")

# %%
try:
     open("imagen.jpg")
     
except FileNotFoundError as err:
    print("Tengo un problema al intentar leer el archivo:", err)
# Out:
# Tengo un problema al intentar leer el archivo: [Errno 2] No such file or directory: 'imagen.jpg'

# %%
try:
     open("configuracion.txt")
except OSError as err:
    if err.errno == 2:
        print("Nadie sabe donde dejaste el archivo configuracion.txt!")
    elif err.errno == 13:
        print("Encontré configuracion.txt pero no pude leerlo")
# Out:
# Nadie sabe donde dejaste el archivo configuracion.txt!

# %% [markdown]
# ## Generación de excepciones

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    return f"Total de agua que queda después de {days_left} días, es de: {total_water_left} litros"

water_left(10, 200, 4)
# Out:
# 'Total de agua que queda después de 4 días, es de: -240 litros'

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    if total_water_left < 0:
        raise RuntimeError(f"No hay suficiente agua para {astronauts} astronautas después {days_left} días!")
    return f"Total de agua que queda después de {days_left} días, es de: {total_water_left} litros"

water_left(5, 100, 2)

# %%
def water_left(astronauts, water_left, days_left):
    for argument in [astronauts, water_left, days_left]:
        try:
            argument / 10
        except TypeError:
            raise TypeError(f"Todos los argumentos deben ser del tipo int, pero recibidos: '{argument}'")
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    if total_water_left < 0:
        raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
    return f"Total water left after {days_left} days is: {total_water_left} liters"

water_left("3", "200", None)
